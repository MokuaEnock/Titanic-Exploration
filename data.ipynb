# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 7.1 MB 242 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd  # handling data and data analysis
import bs4  # data scrapping
import numpy as np  # matrix computations
import requests  # making HTTP requests to the internet
import warnings  # handle odlue warnings
import unicodedata

warnings.filterwarnings("ignore")

# %% [markdown]
# 1. Business Understanding
#     - what problem you are trying to solve.
#     - what is needed for you to solve the problem.
#     - understanding the endgoal
#
# 2. Data collection
#     - Secondary data, primary data or a combination of both.
#     - Setup avenues for data collection - surveys, interviews, questionnaires etc
#
# 3. Data preparation
#     - Data types
#     - Missing values
#     - Data validation
#     - Outliers
#
# 4. Data exploration
#
# 5. Data evaluation
#
# 6. Data modelling
#
# 7. Deployment

# %% [markdown]
# ## Data Collection
#
# we will be utilizing data scrapping to get our data.

# %%
#getting the url to the newegg page
url = "https://www.newegg.com/p/pl?d=laptops&page=2"

#getting the response of the URL
response  = requests.get(url)

# %%
# extracting the html page

from bs4 import BeautifulSoup as bs
soup = bs(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
